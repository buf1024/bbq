# %%
from bbq import *
from bbq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')
pretty_df(intro('zcode'))
# Out:
# <style  type="text/css" >
# #T_1f0a5fb8_880c_11ec_a010_186590d57a6brow0_col0,#T_1f0a5fb8_880c_11ec_a010_186590d57a6brow0_col1{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_1f0a5fb8_880c_11ec_a010_186590d57a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >doc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1f0a5fb8_880c_11ec_a010_186590d57a6blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1f0a5fb8_880c_11ec_a010_186590d57a6brow0_col0" class="data row0 col0" >test.ZCode</td>
#                         <td id="T_1f0a5fb8_880c_11ec_a010_186590d57a6brow0_col1" class="data row0 col1" >  名称: Z形态震荡上涨震荡(基于日线)
#   说明: 右侧上涨爬升震荡的股票
#   参数: min_trade_days -- 最小上市天数(默认: 60)
#         right_horizon_days -- 右侧水平震荡的最大天数(默认: 15)
# ...

# %%
strategy = strategies['test.ZCode'](db=stock, test_end_date='20220207')
await strategy.prepare()
data = await strategy.run()
# Out:
# ...
# 统计 sz002224: 100%|██████████| 1/1 [00:00<00:00, 13.75it/s]

# %%
data
# Out:
#         code  name   close  right_shock_days  rise_days  left_shock_days  \
# 0   sh600018  上港集团    5.48                14          5               19
# 1   sh600085   同仁堂   43.67                 2          5               14
# 2   sh600132  重庆啤酒  157.06                11          3               10
# 3   sh600170  上海建工    3.64                 5          3                7
# 4   sh600180   瑞茂通    7.04                 6          4               26
# 5   sh600187  国中水务    2.51                 3          5               42
# 6   sh600210  紫江企业    9.20                 1          3               18
# 7   sh600217  中再资环    6.97                 1          7                7
# 8   sh600287  江苏舜天    4.47                 3          6               31
# 9   sh600292  远达环保    8.50                 5          3               26
# 10  sh600355  精伦电子    3.17                 3          6                8
# 11  sh600477  杭萧钢构    3.89                 8          4               24
# ...

# %%
charts = await strategy.plots(data)

# %%
charts['sh601618'].render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="878ef774413b4c0492d7ee79e78ffb73" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_878ef774413b4c0492d7ee79e78ffb73 = echarts.init(
#                     document.getElementById('878ef774413b4c0492d7ee79e78ffb73'), 'white', {renderer: 'canvas'});
# ...

# %%
strategy.export_to_path('/Users/luoguochun/Downloads/zcode31.txt', data)
