# %%
from bbq import *
from bbq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')
pretty_df(intro('rightside'))
# Out:
# <style  type="text/css" >
# #T_aab6eb6e_6951_11ec_b249_186590d57a6brow0_col0,#T_aab6eb6e_6951_11ec_b249_186590d57a6brow0_col1{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_aab6eb6e_6951_11ec_b249_186590d57a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >doc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aab6eb6e_6951_11ec_b249_186590d57a6blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aab6eb6e_6951_11ec_b249_186590d57a6brow0_col0" class="data row0 col0" >test.RightSide</td>
#                         <td id="T_aab6eb6e_6951_11ec_b249_186590d57a6brow0_col1" class="data row0 col1" >  名称: 右侧选股(基于日线)
#   说明: 选择右侧上涨的股票
#   参数: min_trade_days -- 最小上市天数(默认: 60)
#         min_con_days -- 最近最小连续上涨天数(默认: 3)
# ...

# %%
strategy = strategies['test.RightSide'](db=stock, test_end_date='20211230')
await strategy.prepare(min_con_days=2, max_con_down=-1, max_con_up=10, judge_days=8, judge_days_up=10, sort_by='rise', )
data = await strategy.run()
# Out:
# ...
# 统计 sh600027: 100%|██████████| 120/120 [00:01<00:00, 83.23it/s]

# %%
pretty_df(data)
# Out:
# <style  type="text/css" >
# ...

# %%
charts = await strategy.plots(data)

# %%
charts['sz002299'].render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6b55605f541846a6bbaad1c273c825aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6b55605f541846a6bbaad1c273c825aa = echarts.init(
#                     document.getElementById('6b55605f541846a6bbaad1c273c825aa'), 'white', {renderer: 'canvas'});
# ...

# %%
strategy.export_to_path('/Users/luoguochun/Downloads/rs30.txt', data)
