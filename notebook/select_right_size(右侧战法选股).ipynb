# %%
from bbq import *
from bbq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')
pretty_df(intro('right'))
# Out:
# <style  type="text/css" >
# #T_d8668dfa_6639_11ec_a81c_186590d57a6brow0_col0,#T_d8668dfa_6639_11ec_a81c_186590d57a6brow0_col1{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_d8668dfa_6639_11ec_a81c_186590d57a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >doc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d8668dfa_6639_11ec_a81c_186590d57a6blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d8668dfa_6639_11ec_a81c_186590d57a6brow0_col0" class="data row0 col0" >test.RightSide</td>
#                         <td id="T_d8668dfa_6639_11ec_a81c_186590d57a6brow0_col1" class="data row0 col1" >  名称: 右侧选股(基于日线)
#   说明: 选择右侧上涨的股票
#   参数: min_trade_days -- 最小上市天数(默认: 60)
#         min_con_days -- 最近最小连续上涨天数(默认: 3)
# ...

# %%
strategy = strategies['test.RightSide'](db=stock, test_end_date='20211224')
await strategy.prepare(min_con_days=2, max_con_up=5, sort_by='rise', judge_days=8, judge_days_up=10)
data = await strategy.run()
# Out:
# ...
# 统计 sh601168: 100%|██████████| 61/61 [00:00<00:00, 74.28it/s]

# %%
pretty_df(data)
# Out:
# <style  type="text/css" >
# ...

# %%
charts = await strategy.plots(data)

# %%
charts['sh601168'].render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="50b41a2acdbc4bf493f4799a23fc4d12" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_50b41a2acdbc4bf493f4799a23fc4d12 = echarts.init(
#                     document.getElementById('50b41a2acdbc4bf493f4799a23fc4d12'), 'white', {renderer: 'canvas'});
# ...

# %%
strategy.export_to_path('/Users/luoguochun/Downloads/a.txt', data)
